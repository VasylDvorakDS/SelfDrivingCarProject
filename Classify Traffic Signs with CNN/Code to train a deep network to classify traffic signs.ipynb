# %% [markdown]
# # CODE TO CLASSIFY TRAFFIC SIGNS

# %% [markdown]
# Citation
#
# J. Stallkamp, M. Schlipsing, J. Salmen, and C. Igel. The German Traffic Sign Recognition Benchmark: A multi-class classification competition. In Proceedings of the IEEE International Joint Conference on Neural Networks, pages 1453–1460. 2011.
#
# @inproceedings{Stallkamp-IJCNN-2011,
#     author = {Johannes Stallkamp and Marc Schlipsing and Jan Salmen and Christian Igel},
#     booktitle = {IEEE International Joint Conference on Neural Networks},
#     title = {The {G}erman {T}raffic {S}ign {R}ecognition {B}enchmark: A multi-class classification competition},
#     year = {2011},
#     pages = {1453--1460}
# }

# %% [markdown]
# - ( 0, b'Speed limit (20km/h)') ( 1, b'Speed limit (30km/h)')
# - ( 2, b'Speed limit (50km/h)') ( 3, b'Speed limit (60km/h)')
# - ( 4, b'Speed limit (70km/h)') ( 5, b'Speed limit (80km/h)')
# - ( 6, b'End of speed limit (80km/h)') ( 7, b'Speed limit (100km/h)')
# - ( 8, b'Speed limit (120km/h)') ( 9, b'No passing')
# - (10, b'No passing for vehicles over 3.5 metric tons')
# - (11, b'Right-of-way at the next intersection') (12, b'Priority road')
# - (13, b'Yield') (14, b'Stop') (15, b'No vehicles')
# - (16, b'Vehicles over 3.5 metric tons prohibited') (17, b'No entry')
# - (18, b'General caution') (19, b'Dangerous curve to the left')
# - (20, b'Dangerous curve to the right') (21, b'Double curve')
# - (22, b'Bumpy road') (23, b'Slippery road')
# - (24, b'Road narrows on the right') (25, b'Road work')
# - (26, b'Traffic signals') (27, b'Pedestrians') (28, b'Children crossing')
# - (29, b'Bicycles crossing') (30, b'Beware of ice/snow')
# - (31, b'Wild animals crossing')
# - (32, b'End of all speed and passing limits') (33, b'Turn right ahead')
# - (34, b'Turn left ahead') (35, b'Ahead only') (36, b'Go straight or right')
# - (37, b'Go straight or left') (38, b'Keep right') (39, b'Keep left')
# - (40, b'Roundabout mandatory') (41, b'End of no passing')
# - (42, b'End of no passing by vehicles over 3.5 metric tons')

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
# import libraries 
import pickle

import pandas as pd # Import Pandas for data manipulation using dataframes
import numpy as np # Import Numpy for data statistical analysis 
import matplotlib.pyplot as plt # Import matplotlib for data visualisation
import random

# %%
with open("./traffic-signs-data/train.p", mode='rb') as training_data:
    train = pickle.load(training_data)
with open("./traffic-signs-data/valid.p", mode='rb') as validation_data:
    valid = pickle.load(validation_data)
with open("./traffic-signs-data/test.p", mode='rb') as testing_data:
    test = pickle.load(testing_data)

# %%
X_train, y_train = train['features'], train['labels']
X_validation, y_validation = valid['features'], valid['labels']
X_test, y_test = test['features'], test['labels']

# %%
X_train.shape
# Out:
# (34799, 32, 32, 3)

# %%
y_train.shape
# Out:
# (34799,)

# %% [markdown]
# # IMAGE EXPLORATION

# %%
i = 1001
plt.imshow(X_train[i]) # Show images are not shuffled
y_train[i]
# Out:
# 36

# %% [markdown]
# # DATA PEPARATION

# %%
## Shuffle the dataset 
from sklearn.utils import shuffle
X_train, y_train = shuffle(X_train, y_train)

# %%
X_train_gray = np.sum(X_train/3, axis=3, keepdims=True)
X_test_gray  = np.sum(X_test/3, axis=3, keepdims=True)
X_validation_gray  = np.sum(X_validation/3, axis=3, keepdims=True)

# %%
X_train_gray_norm = (X_train_gray - 128)/128 
X_test_gray_norm = (X_test_gray - 128)/128
X_validation_gray_norm = (X_validation_gray - 128)/128

# %%
X_train_gray.shape
# Out:
# (34799, 32, 32, 1)

# %%
i = 610
plt.imshow(X_train_gray[i].squeeze(), cmap='gray')
plt.figure()
plt.imshow(X_train[i])

# %% [markdown]
# # MODEL TRAINING

# %%
# Import train_test_split from scikit library
# Import Keras
# import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dense, Flatten, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import TensorBoard

# from subprocess import check_output
from sklearn.model_selection import train_test_split

# %%
image_shape = X_train_gray[i].shape

# %%
cnn_model = Sequential()
cnn_model.add(Conv2D(64,3, 3, input_shape = image_shape, activation='relu'))
cnn_model.add(MaxPooling2D(pool_size = (2, 2)))
cnn_model.add(Flatten())
cnn_model.add(Dense(64, activation = 'relu'))
cnn_model.add(Dense(43, activation = 'sigmoid'))

# %%
cnn_model.compile(loss ='sparse_categorical_crossentropy', optimizer=Adam(learning_rate=0.001),metrics =['accuracy'])

# %%
history = cnn_model.fit(X_train_gray_norm,
                        y_train,
                        batch_size=500,
                        epochs=50,
                        verbose=1,
                        validation_data = (X_validation_gray_norm,y_validation))
# Out:
# Epoch 1/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.1078 - loss: 3.4394 - val_accuracy: 0.2224 - val_loss: 3.0957
# Epoch 2/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.3407 - loss: 2.5902 - val_accuracy: 0.3642 - val_loss: 2.3838
# Epoch 3/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.5119 - loss: 1.8420 - val_accuracy: 0.5025 - val_loss: 1.9013
# Epoch 4/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6218 - loss: 1.4134 - val_accuracy: 0.5476 - val_loss: 1.6985
# Epoch 5/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.6773 - loss: 1.1970 - val_accuracy: 0.6007 - val_loss: 1.4879
# Epoch 6/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.7261 - loss: 1.0098 - val_accuracy: 0.6057 - val_loss: 1.4258
# Epoch 7/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.7532 - loss: 0.9110 - val_accuracy: 0.6501 - val_loss: 1.3145
# Epoch 8/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.7721 - loss: 0.8252 - val_accuracy: 0.6590 - val_loss: 1.2872
# Epoch 9/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.7910 - loss: 0.7562 - val_accuracy: 0.6635 - val_loss: 1.2378
# Epoch 10/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8052 - loss: 0.6985 - val_accuracy: 0.6646 - val_loss: 1.2349
# Epoch 11/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8191 - loss: 0.6663 - val_accuracy: 0.6853 - val_loss: 1.2064
# Epoch 12/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8260 - loss: 0.6268 - val_accuracy: 0.6696 - val_loss: 1.2098
# Epoch 13/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8433 - loss: 0.5846 - val_accuracy: 0.7082 - val_loss: 1.1649
# Epoch 14/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8517 - loss: 0.5537 - val_accuracy: 0.7048 - val_loss: 1.1269
# Epoch 15/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8570 - loss: 0.5245 - val_accuracy: 0.7163 - val_loss: 1.1302
# Epoch 16/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8640 - loss: 0.5018 - val_accuracy: 0.7256 - val_loss: 1.1046
# Epoch 17/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8697 - loss: 0.4806 - val_accuracy: 0.7220 - val_loss: 1.1146
# Epoch 18/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8762 - loss: 0.4702 - val_accuracy: 0.7499 - val_loss: 1.0815
# Epoch 19/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8853 - loss: 0.4379 - val_accuracy: 0.7401 - val_loss: 1.0673
# Epoch 20/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8891 - loss: 0.4269 - val_accuracy: 0.7163 - val_loss: 1.1136
# Epoch 21/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8934 - loss: 0.4107 - val_accuracy: 0.7338 - val_loss: 1.1022
# Epoch 22/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.8959 - loss: 0.3957 - val_accuracy: 0.7474 - val_loss: 1.0535
# Epoch 23/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.9003 - loss: 0.3822 - val_accuracy: 0.7388 - val_loss: 1.1084
# Epoch 24/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9049 - loss: 0.3676 - val_accuracy: 0.7578 - val_loss: 1.0672
# Epoch 25/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9038 - loss: 0.3613 - val_accuracy: 0.7465 - val_loss: 1.0920
# Epoch 26/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.8992 - loss: 0.3581 - val_accuracy: 0.7501 - val_loss: 1.0871
# Epoch 27/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9084 - loss: 0.3415 - val_accuracy: 0.7639 - val_loss: 1.0666
# Epoch 28/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9144 - loss: 0.3267 - val_accuracy: 0.7701 - val_loss: 1.0649
# Epoch 29/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9118 - loss: 0.3269 - val_accuracy: 0.7551 - val_loss: 1.0782
# Epoch 30/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9183 - loss: 0.3111 - val_accuracy: 0.7612 - val_loss: 1.0931
# Epoch 31/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9191 - loss: 0.3030 - val_accuracy: 0.7512 - val_loss: 1.1050
# Epoch 32/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9195 - loss: 0.2995 - val_accuracy: 0.7739 - val_loss: 1.0776
# Epoch 33/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9260 - loss: 0.2850 - val_accuracy: 0.7642 - val_loss: 1.1202
# Epoch 34/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9266 - loss: 0.2868 - val_accuracy: 0.7633 - val_loss: 1.0737
# Epoch 35/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9282 - loss: 0.2726 - val_accuracy: 0.7780 - val_loss: 1.0698
# Epoch 36/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.9239 - loss: 0.2790 - val_accuracy: 0.7773 - val_loss: 1.0368
# Epoch 37/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9325 - loss: 0.2540 - val_accuracy: 0.7653 - val_loss: 1.1321
# Epoch 38/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9331 - loss: 0.2529 - val_accuracy: 0.7766 - val_loss: 1.0858
# Epoch 39/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9372 - loss: 0.2492 - val_accuracy: 0.7574 - val_loss: 1.1139
# Epoch 40/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9310 - loss: 0.2551 - val_accuracy: 0.7533 - val_loss: 1.1024
# Epoch 41/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9379 - loss: 0.2347 - val_accuracy: 0.7728 - val_loss: 1.1313
# Epoch 42/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9401 - loss: 0.2349 - val_accuracy: 0.7712 - val_loss: 1.1020
# Epoch 43/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9445 - loss: 0.2222 - val_accuracy: 0.7741 - val_loss: 1.0876
# Epoch 44/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9392 - loss: 0.2310 - val_accuracy: 0.7837 - val_loss: 1.0991
# Epoch 45/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9458 - loss: 0.2151 - val_accuracy: 0.7821 - val_loss: 1.1123
# Epoch 46/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9425 - loss: 0.2180 - val_accuracy: 0.7533 - val_loss: 1.1643
# Epoch 47/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9364 - loss: 0.2305 - val_accuracy: 0.7832 - val_loss: 1.1068
# Epoch 48/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9460 - loss: 0.2092 - val_accuracy: 0.7728 - val_loss: 1.1234
# Epoch 49/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9494 - loss: 0.2044 - val_accuracy: 0.7798 - val_loss: 1.1212
# Epoch 50/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9531 - loss: 0.1947 - val_accuracy: 0.7707 - val_loss: 1.1880

# %%
score = cnn_model.evaluate(X_test_gray_norm, y_test,verbose=0)
print('Test Accuracy : {:.4f}'.format(score[1]))
# Out:
# Test Accuracy : 0.7673

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(len(accuracy))
plt.plot(epochs, accuracy, 'bo', label='Training Accuracy')
plt.plot(epochs, val_accuracy, 'b', label='Validation Accuracy')
plt.title('Training and Validation accuracy')
plt.legend()
plt.figure()
plt.plot(epochs, loss, 'bo', label='Training Loss')
plt.plot(epochs, val_loss, 'b', label='Validation Loss')
plt.title('Training and validation loss')
plt.legend()
plt.show()

# %%
#get the predictions for the test data

# Deprecated way pre-Tensorflow 2.6:
#predicted_classes = cnn_model.predict_classes(X_test_gray_norm)

# New way:
predict_x = cnn_model.predict(X_test_gray_norm)
predicted_classes = np.argmax(predict_x, axis=1)

#get the indices to be plotted
y_true = y_test
# Out:
# 395/395 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_true, predicted_classes)
cm
# Out:
# array([[ 20,  17,   6, ...,   0,   0,   0],
#        [160, 474,  37, ...,   3,   0,   0],
#        [110, 112, 418, ...,   3,   0,   0],
#        ...,
#        [  1,   9,  21, ...,  21,   0,   0],
#        [  0,   0,   0, ...,   0,   5,   2],
#        [  0,   1,   0, ...,   0,  22,  45]], dtype=int64)

# %%
for i in range(0,12):
    plt.subplot(4,3,i+1)
    plt.imshow(X_test_gray_norm[i+10].squeeze(), cmap='gray', interpolation='none')
    plt.title("Predicted {}, Class {}".format(predicted_classes[i+10], y_true[i+10]))
    plt.tight_layout()
